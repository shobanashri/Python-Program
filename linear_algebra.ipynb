# %% [markdown]
# <a href="https://colab.research.google.com/github/shobanashri/Python-Program/blob/main/linear_algebra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **```A BANK ROBBER CAUGHT```**

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
t = np.linspace(0,40,1000)

# %%
d_r = 2.5*t

# %%
d_s = 3*(t-5)

# %%
fig, ax = plt.subplots()
plt.title("A Bank Robber Caught")
plt.xlabel("time")
plt.ylabel("distance")
ax.set_xlim([0,40])
ax.set_ylim([0,100])
ax.plot(t,d_r,c='green')
ax.plot(t,d_s,c='brown')
plt.axvline(x=30, color ="purple", linestyle = '--')
_ = plt.axhline(y=75, color = "purple", linestyle = '--')

# %% [markdown]
# # **SCALARS**

# %% [markdown]
# ```TENSORFLOW```

# %%
import tensorflow as tf

# %%
x = tf.Variable(25,dtype=tf.int16)
x
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int16, numpy=25>

# %%
x.shape
# Out:
# TensorShape([])

# %%
y = tf.Variable(18, dtype=tf.int16)
y
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int16, numpy=18>

# %%
sum_tf = tf.add(x,y)
sum_tf
# Out:
# <tf.Tensor: shape=(), dtype=int16, numpy=43>

# %% [markdown]
# # **vectors** - 1D array

# %% [markdown]
# numpy

# %%
import numpy as np

# %%
x = np.array([25,2,5])

# %%
len(x)
# Out:
# 3

# %%
x.shape
# Out:
# (3,)

# %%
y = np.array([[25,2,5]])

# %%
y.shape
# Out:
# (1, 3)

# %%
x_t = x.T
x_t
# Out:
# array([25,  2,  5])

# %%
x_t.shape
# Out:
# (3,)

# %%
y_t = y.T
y_t
# Out:
# array([[25],
#        [ 2],
#        [ 5]])

# %%
y_t.shape
# Out:
# (3, 1)

# %% [markdown]
# # **VECTOR TRANSPORTATION**

# %% [markdown]
# ZERO VECTORS

# %%
Z = np.zeros(3)
Z
# Out:
# array([0., 0., 0.])

# %% [markdown]
# VECTOR IN PYTORCH AND TENSORFLOW

# %%
import torch

# %% [markdown]
# creating tensor

# %%
x_pt = torch.tensor([25,2,5])
x_pt
# Out:
# tensor([25,  2,  5])

# %% [markdown]
# variable method

# %%
x_tf = tf.Variable([25,2,5])
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=(3,) dtype=int32, numpy=array([25,  2,  5], dtype=int32)>
